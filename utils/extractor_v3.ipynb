# %%
import requests
import pandas as pd
import json
import base64
import os
from datetime import datetime
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import traceback
from dotenv import load_dotenv

# Cargar variables de entorno desde el archivo .env
load_dotenv()

# Configuración de VALD
CLIENT_ID = os.getenv('CLIENT_ID')
CLIENT_SECRET = os.getenv('CLIENT_SECRET')
# FECHA_DESDE = os.getenv('FECHA_DESDE')
FECHA_DESDE= '2023-01-01T00:00:00.000Z'

# Crear directorio para guardar los CSV si no existe
OUTPUT_DIR = "output_data"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
# Función para obtener token
def get_token():
    token_url = "https://security.valdperformance.com/connect/token"
    
    payload = {
        "grant_type": "client_credentials",
        "client_id": CLIENT_ID,
        "client_secret": CLIENT_SECRET
    }
    
    try:
        response = requests.post(token_url, data=payload)
        
        if response.status_code == 200:
            token_data = response.json()
            print("✅ Autenticación exitosa")
            return token_data.get('access_token')
        else:
            print(f"❌ Error en la autenticación: {response.status_code}")
            print(response.text)
            return None
            
    except Exception as e:
        print(f"❌ Error inesperado: {str(e)}")
        return None

# Función para obtener tenants
def get_tenants(token):
    url = "https://prd-use-api-externaltenants.valdperformance.com/tenants"
    
    headers = {
        "Authorization": f"Bearer {token}",
        "Accept": "application/json"
    }
    
    try:
        response = requests.get(url, headers=headers)
        
        if response.status_code == 200:
            tenants_data = response.json()
            df_tenants = pd.DataFrame(tenants_data['tenants'])
            
            # Guardar a CSV
            csv_path = os.path.join(OUTPUT_DIR, "tenants.csv")
            df_tenants.to_csv(csv_path, index=False)
            print(f"✅ Datos de tenants guardados en {csv_path}")
            
            return df_tenants
        else:
            print(f"❌ Error al obtener tenants: {response.status_code}")
            return pd.DataFrame()
            
    except Exception as e:
        print(f"❌ Error inesperado: {str(e)}")
        return pd.DataFrame()

# Función para obtener categorías
def get_categories(tenant_id, token):
    url = "https://prd-use-api-externaltenants.valdperformance.com/categories"
    
    headers = {
        "Authorization": f"Bearer {token}",
        "Accept": "application/json"
    }
    
    params = {
        "TenantId": tenant_id
    }
    
    try:
        print("🔄 Solicitando categories a la API...")
        response_categories = requests.get(url, headers=headers, params=params)
        
        if response_categories.status_code != 200:
            print(f"❌ Error al obtener categorías: {response_categories.status_code}")
            return pd.DataFrame()
            
        categories = json.loads(response_categories.content.decode('utf-8'))
        df_categories_ = pd.DataFrame(categories['categories'])
        df_categories_['tenant_id'] = tenant_id
        
        # Guardar a CSV
        csv_path = os.path.join(OUTPUT_DIR, f"categories_{tenant_id}.csv")
        df_categories_.to_csv(csv_path, index=False)
        print(f"✅ Categorías para tenant {tenant_id} guardadas en {csv_path}")
        
        return df_categories_
        
    except Exception as e:
        print(f"❌ Error al obtener categorías: {str(e)}")
        return pd.DataFrame()

# Función para obtener grupos
def get_groups(tenant_id, token):
    url = "https://prd-use-api-externaltenants.valdperformance.com/groups"
    
    headers = {
        "Authorization": f"Bearer {token}",
        "Accept": "application/json"
    }
    
    params = {
        "TenantId": tenant_id
    }
    
    try:
        print("🔄 Solicitando grupos a la API...")
        response_groups = requests.get(url, headers=headers, params=params)
        
        if response_groups.status_code != 200:
            print(f"❌ Error al obtener grupos: {response_groups.status_code}")
            return pd.DataFrame()
            
        groups = json.loads(response_groups.content.decode('utf-8'))
        df_groups_ = pd.DataFrame(groups['groups'])
        df_groups_['tenant_id'] = tenant_id
        
        # Guardar a CSV
        csv_path = os.path.join(OUTPUT_DIR, f"groups_{tenant_id}.csv")
        df_groups_.to_csv(csv_path, index=False)
        print(f"✅ Grupos para tenant {tenant_id} guardados en {csv_path}")
        
        return df_groups_
        
    except Exception as e:
        print(f"❌ Error al obtener grupos: {str(e)}")
        return pd.DataFrame()

# Función para obtener perfiles
def get_profiles(token, tenant_id, groupId, groupName, categoryId, categoryName, df_all_profiles=None):
    url = "https://prd-use-api-externalprofile.valdperformance.com/profiles"
    
    headers = {
        "Authorization": f"Bearer {token}",
        "Accept": "application/json"
    }
    
    params = {
        "TenantId": tenant_id,
        "groupId": groupId
    }
    
    try:
        print(f"🔄 Solicitando perfiles para grupo {groupName}...")
        response_profiles = requests.get(url, headers=headers, params=params)
        
        if response_profiles.status_code != 200:
            print(f"⚠️ Error HTTP {response_profiles.status_code} para grupo {groupName}")
            return df_all_profiles if df_all_profiles is not None else pd.DataFrame()
        
        if not response_profiles.content or response_profiles.content == b'':
            print(f"⚠️ Respuesta vacía para grupo {groupName}")
            return df_all_profiles if df_all_profiles is not None else pd.DataFrame()
        
        content_str = response_profiles.content.decode('utf-8')
        
        if not content_str.strip():
            print(f"⚠️ Contenido vacío para grupo {groupName}")
            return df_all_profiles if df_all_profiles is not None else pd.DataFrame()
            
        profiles = json.loads(content_str)
        
        if 'profiles' not in profiles:
            print(f"⚠️ Estructura JSON inesperada para grupo {groupName}")
            return df_all_profiles if df_all_profiles is not None else pd.DataFrame()
        
        if not profiles['profiles']:
            print(f"ℹ️ No hay perfiles para el grupo {groupName}")
            return df_all_profiles if df_all_profiles is not None else pd.DataFrame()
        
        df_profiles_ = pd.DataFrame(profiles['profiles'])
        
        df_profiles_['tenant_id'] = tenant_id
        df_profiles_['groupId'] = groupId
        df_profiles_['groupName'] = groupName
        df_profiles_['categoryId'] = categoryId
        df_profiles_['categoryName'] = categoryName
        
        # Si ya tenemos un DataFrame de todos los perfiles, concatenamos
        if df_all_profiles is not None:
            df_all_profiles = pd.concat([df_all_profiles, df_profiles_], ignore_index=True)
        else:
            df_all_profiles = df_profiles_
        
        print(f"✅ {len(df_profiles_)} perfiles obtenidos para grupo {groupName}")
        
        return df_all_profiles
        
    except json.JSONDecodeError as e:
        print(f"❌ Error JSON para grupo {groupName}: {e}")
        return df_all_profiles if df_all_profiles is not None else pd.DataFrame()
    except Exception as e:
        print(f"❌ Error inesperado para grupo {groupName}: {e}")
        return df_all_profiles if df_all_profiles is not None else pd.DataFrame()


def get_nordbord_complete(token, tenant_id, fecha_desde, profile_id=None):
    """
    Obtiene TODOS los datos de NordBord usando la paginación correcta del endpoint /tests/v2
    """
    base_url = "https://prd-use-api-externalnordbord.valdperformance.com"
    endpoint = "/tests/v2"
    
    headers = {
        "Authorization": f"Bearer {token}"
    }
    
    all_tests = []  # Cambiado para ser más específico
    current_modified_from = fecha_desde
    page_count = 0
    
    print(f"🔄 Iniciando obtención completa de datos NordBord para tenant {tenant_id}...")
    
    while True:
        page_count += 1
        print(f"📄 Procesando página {page_count} (desde: {current_modified_from})")
        
        params = {
            "tenantId": tenant_id,
            "modifiedFromUtc": current_modified_from
        }
        
        if profile_id:
            params["profileId"] = profile_id
        
        try:
            response = requests.get(f"{base_url}{endpoint}", params=params, headers=headers)
            
            if response.status_code == 200:
                datos = response.json()
                
                # Determinar la estructura de los datos
                if isinstance(datos, list):
                    current_batch = datos
                elif isinstance(datos, dict):
                    # Buscar diferentes posibles keys
                    if 'tests' in datos:
                        current_batch = datos['tests']
                    elif 'items' in datos:
                        current_batch = datos['items']
                    elif 'data' in datos:
                        current_batch = datos['data']
                    else:
                        # Si es un dict sin keys conocidas, tratarlo como un solo elemento
                        current_batch = [datos]
                else:
                    current_batch = [datos] if datos else []
                
                if not current_batch:
                    print("✅ No hay más datos en esta respuesta")
                    break
                
                print(f"📊 Obtenidos {len(current_batch)} registros en esta página")
                
                # Agregar datos a la lista principal
                all_tests.extend(current_batch)
                
                # CLAVE: Buscar el campo de fecha de modificación para paginación
                last_record = current_batch[-1]
                next_modified_date = None
                
                # Buscar diferentes posibles nombres para el campo de fecha
                possible_date_fields = ['modifiedDateUtc', 'modifiedDate', 'lastModified', 
                                      'updatedAt', 'dateModified', 'modified']
                
                for field in possible_date_fields:
                    if field in last_record:
                        next_modified_date = last_record[field]
                        print(f"🔄 Encontrado campo '{field}': {next_modified_date}")
                        break
                
                if next_modified_date:
                    # Verificar si la fecha es la misma que la anterior (bucle infinito)
                    if next_modified_date == current_modified_from:
                        print("⚠️ Detectado bucle infinito: misma fecha de modificación")
                        print("🔄 Agregando 1 milisegundo para avanzar...")
                        
                        # Convertir a datetime, agregar 1 milisegundo, y volver a string
                        from datetime import datetime, timedelta
                        try:
                            dt = datetime.fromisoformat(next_modified_date.replace('Z', '+00:00'))
                            dt_next = dt + timedelta(milliseconds=1)
                            current_modified_from = dt_next.strftime('%Y-%m-%dT%H:%M:%S.%f')[:-3] + 'Z'
                            print(f"🔄 Nueva fecha: {current_modified_from}")
                        except Exception as e:
                            print(f"❌ Error al procesar fecha: {e}")
                            break
                    else:
                        current_modified_from = next_modified_date
                        print(f"🔄 Siguiente página desde: {current_modified_from}")
                else:
                    print("⚠️ No se encontró campo de fecha de modificación en el último registro")
                    print(f"⚠️ Campos disponibles: {list(last_record.keys())}")
                    break
                
                # Protección adicional contra bucles infinitos
                if page_count > 1000:  # Máximo 1000 páginas
                    print("⚠️ Alcanzado límite máximo de páginas (1000). Deteniendo...")
                    break
                
            elif response.status_code == 204:
                print("✅ Código 204 - No hay más registros para obtener")
                break
                
            else:
                print(f"❌ Error {response.status_code}: {response.text}")
                break
                
        except Exception as e:
            print(f"❌ Error en la solicitud: {str(e)}")
            break
    
    # Convertir a DataFrame
    if all_tests:
        df = pd.DataFrame(all_tests)
        
        # Convertir columnas de fecha (sin el warning)
        date_columns = [col for col in df.columns 
                       if 'date' in col.lower() or 'time' in col.lower()]
        for col in date_columns:
            try:
                df[col] = pd.to_datetime(df[col])
            except:
                pass  # Si no se puede convertir, mantener el formato original
        
        # Añadir información del tenant
        df['tenant_id'] = tenant_id
        
        print(f"🎉 Proceso completado: {len(df)} registros totales obtenidos en {page_count} páginas")
        return df
    else:
        print("⚠️ No se obtuvieron datos")
        return pd.DataFrame()

# %%
# Obtener token
token = get_token()
if not token:
    print("❌ No se pudo obtener el token. Proceso cancelado.")

# Obtener tenants
df_tenants = get_tenants(token)
if df_tenants.empty:
    print("❌ No se pudieron obtener los tenants. Proceso cancelado.")

# Inicializar DataFrames para consolidar datos
df_all_profiles = pd.DataFrame()
df_all_nordbord = pd.DataFrame()
# Out:
# ✅ Autenticación exitosa
# ✅ Datos de tenants guardados en output_data/tenants.csv

# %%
tenant_id = df_tenants['id'].loc[0]
tenant_name = df_tenants['name'].loc[0]
print(tenant_id)
print(tenant_name)
# Out:
# f1185650-fb79-44a0-8b4b-b2bf82d28c83
# STAFF - Luciano Tomagheli

# %%
# Obtener categorías
df_categories = get_categories(tenant_id, token)
df_categories
# Out:
# 🔄 Solicitando categories a la API...
# ✅ Categorías para tenant f1185650-fb79-44a0-8b4b-b2bf82d28c83 guardadas en output_data/categories_f1185650-fb79-44a0-8b4b-b2bf82d28c83.csv
#                                       id syncId               name  \
# 0   d9a94657-6111-4993-a5fe-081b21f15b75   None             Import
# 1   58734421-a5ed-420c-a9d5-26c5b0eda5d4   None         Categorias
# 2   f021a645-f179-49bd-9181-30a433c19672   None               Test
# 3   eac290e8-77a8-45ee-85cd-3c15d8acb9f0   None        CBMM Hockey
# 4   00031b91-0b46-445e-ab45-40fe3b4964c7   None           Vald CSM
# 5   a48fa3ba-e1da-4502-8ddb-4558fb7210ba   None              Agile
# 6   f6093938-5d89-44d4-b0fa-48c30423b0b6   None    fuerzas basicas
# 7   82f698f2-7a4b-41bb-958b-5f01defafd28   None            Deporte
# 8   83a00bde-14e5-4d67-8fd4-6011b6118fa8   None  Proyecto Crossfit
# 9   8a53265b-a484-4fbb-9ae0-64e1a0daf47f   None                HSI
# 10  e0afcae8-4d92-4203-b0c5-6b7e6ea7029d   None            Amateur
# 11  5ad747f7-41e7-44b4-a0c3-864efa8a8aa8   None      Rugby Academy
# 12  6c879d6e-f098-40a5-b743-8d4f0ef12db7   None   Plantel Superior
# 13  04504bd3-f686-4dce-8361-968f01c75a01   None           Esportes
# 14  607c24b5-c7b4-4920-a929-a1e68077ce9e   None       HSI Research
# 15  1fdd0100-6c2f-48c4-8f92-a685fb5af643   None             Lesion
# 16  0c95ced6-ca03-460f-bd3d-abefb73b2c78   None            CARRERA
# 17  bee5bb48-4759-4705-8474-b5fc4a111e7d   None               CARP
# 18  5bac6d7d-2999-48e3-90e9-b84f788ed31f   None            Equipos
# 19  2615dbc1-502d-4a48-9522-b8a3d5e3fe5a   None               Team
# 20  abfd3e98-0024-491a-95e9-cd8d91a9d0e8   None           Posicion
# 21  e66e443b-e77c-4f10-9fba-cfd31c68cd2f   None           UdeAndes
# 22  504c6c18-69a7-4ea0-a056-e0bc7d733196   None    Hockey Femenino
# 23  445ef65d-2857-48ff-b911-e6b658c74ba6   None          Condicion
# 24  0e7bfdff-aabb-4efa-ad13-ecb419e0beef   None               CBMM
# 25  85561d51-b08f-4c5e-94d8-f06b110339dd   None            Academy
# 26  0db9ae1a-2464-463a-856c-f5510fe270cf   None      Uncategorised
# 27  7e5866f2-86f8-4c0a-a0c8-f684eef6a3b0   None              Rugby
# 28  0cd2d321-8c80-41fc-bab3-fd98c53bb178   None                CAM
#
#                                tenant_id
# 0   f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 1   f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 2   f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 3   f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 4   f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 5   f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 6   f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 7   f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 8   f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 9   f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 10  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 11  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 12  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 13  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 14  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 15  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 16  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 17  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 18  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 19  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 20  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 21  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 22  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 23  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 24  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 25  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 26  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 27  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 28  f1185650-fb79-44a0-8b4b-b2bf82d28c83

# %%
df_categories = df_categories[df_categories['name'] == 'CBMM']
df_categories
# Out:
#                                       id syncId  name  \
# 24  0e7bfdff-aabb-4efa-ad13-ecb419e0beef   None  CBMM
#
#                                tenant_id
# 24  f1185650-fb79-44a0-8b4b-b2bf82d28c83

# %%
# Obtener grupos
df_groups = get_groups(tenant_id, token)
df_groups
# Out:
# 🔄 Solicitando grupos a la API...
# ✅ Grupos para tenant f1185650-fb79-44a0-8b4b-b2bf82d28c83 guardados en output_data/groups_f1185650-fb79-44a0-8b4b-b2bf82d28c83.csv
#                                        id       name  \
# 0    c6987553-a658-461c-9fe2-d09879d2cb00          1
# 1    2d907f1f-caff-4e4b-9790-8bd304b0fbba          2
# 2    db806a4b-8ae2-40f7-a5a0-7061f3026589          3
# 3    84cfb5d3-cd9d-49b9-83c2-30748bc8524d          4
# 4    b5d30982-020a-4c63-ab6e-f60db009878e        4ta
# ..                                    ...        ...
# 106  04f8f2b4-39dd-4dec-8131-d04f20aea0c0  Velez 7ma
# 107  9f98fb01-0cbe-4ed6-9e3b-b78b37c91097  Velez 8va
# 108  228d7637-5e50-4491-adb0-745fbcedd0d8  Velez 9na
# 109  6d04667e-5dc9-4172-8281-5b7da1c669a7       Wing
# 110  754e1fad-e057-4999-bac0-3b0b9a20afbc        Yes
#
#                                categoryId syncId  \
# 0    5ad747f7-41e7-44b4-a0c3-864efa8a8aa8   None
# 1    5ad747f7-41e7-44b4-a0c3-864efa8a8aa8   None
# 2    5ad747f7-41e7-44b4-a0c3-864efa8a8aa8   None
# 3    5ad747f7-41e7-44b4-a0c3-864efa8a8aa8   None
# 4    58734421-a5ed-420c-a9d5-26c5b0eda5d4   None
# ..                                    ...    ...
# 106  5bac6d7d-2999-48e3-90e9-b84f788ed31f   None
# 107  5bac6d7d-2999-48e3-90e9-b84f788ed31f   None
# 108  5bac6d7d-2999-48e3-90e9-b84f788ed31f   None
# 109  abfd3e98-0024-491a-95e9-cd8d91a9d0e8   None
# 110  8a53265b-a484-4fbb-9ae0-64e1a0daf47f   None
#
#                                 tenant_id
# 0    f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 1    f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 2    f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 3    f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 4    f1185650-fb79-44a0-8b4b-b2bf82d28c83
# ..                                    ...
# 106  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 107  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 108  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 109  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 110  f1185650-fb79-44a0-8b4b-b2bf82d28c83
#
# [111 rows x 5 columns]

# %%
df_groups = df_groups[df_groups['categoryId'] == '0e7bfdff-aabb-4efa-ad13-ecb419e0beef']

# %%
# Si hay categorías y grupos, combinarlos
if not df_categories.empty and not df_groups.empty:
    # Combinar grupos con categorías
    df_groups_with_category = df_groups.merge(
        df_categories[['id', 'name']].rename(columns={'name': 'category_name'}),
        left_on='categoryId',
        right_on='id',
        how='left'
    )
    
    # Limpiar columnas duplicadas
    if 'id_y' in df_groups_with_category.columns:
        df_groups_with_category = df_groups_with_category.drop(columns=['id_y'])
        df_groups_with_category = df_groups_with_category.rename(columns={'id_x': 'id'})
    
    # Guardar grupos con categorías
    csv_path = os.path.join(OUTPUT_DIR, f"groups_with_categories_{tenant_id}.csv")
    df_groups_with_category.to_csv(csv_path, index=False)
    print(f"✅ Grupos con categorías guardados en {csv_path}")
    
    # Obtener perfiles por grupo
    print("\n📊 Obteniendo perfiles para cada grupo...")
    for idx, group in df_groups_with_category.iterrows():
        df_all_profiles = get_profiles(
            token, 
            tenant_id, 
            group['id'], 
            group['name'], 
            group['categoryId'], 
            group.get('category_name', ''),
            df_all_profiles
        )
# Out:
# ✅ Grupos con categorías guardados en output_data/groups_with_categories_f1185650-fb79-44a0-8b4b-b2bf82d28c83.csv
#
# 📊 Obteniendo perfiles para cada grupo...
# 🔄 Solicitando perfiles para grupo Inactivos...
# ✅ 4 perfiles obtenidos para grupo Inactivos
# 🔄 Solicitando perfiles para grupo M15 2025...
# ✅ 42 perfiles obtenidos para grupo M15 2025
# 🔄 Solicitando perfiles para grupo M16 2025...
# ✅ 37 perfiles obtenidos para grupo M16 2025
# 🔄 Solicitando perfiles para grupo M17 2025...
# ✅ 52 perfiles obtenidos para grupo M17 2025
# 🔄 Solicitando perfiles para grupo M19 2025...
# ✅ 62 perfiles obtenidos para grupo M19 2025
# 🔄 Solicitando perfiles para grupo Plantel Superior...
# ✅ 169 perfiles obtenidos para grupo Plantel Superior

# %%
df_all_profiles
# Out:
#                                 profileId syncId  givenName     familyName  \
# 0    1dd48a20-d55d-4be3-9ce1-1ef41ea4e3a5   None    IGNACIO           RUIZ
# 1    63016c13-015e-483f-864e-77b8117ed937   None  VALENTINO       PRECIOZA
# 2    d9c83db9-7479-4610-959a-7ffbf7334f30   None   BAUTISTA  JAUREGUIBERRY
# 3    1de99470-2457-4e8d-8891-c69b92fcdecf   None      FELIX    DE BATTISTA
# 4    e4b9df41-8f92-4470-859d-02e2c0c82b6c   None   BENJAMIN     DOS SANTOS
# ..                                    ...    ...        ...            ...
# 361  961222de-6cc1-4cce-9d56-fa7b61589d0a   None       Facu         Marino
# 362  c4987963-2287-489b-a769-fb003bda1560   None      Bravi        Antonio
# 363  9f42d5d4-0e2b-485e-9e91-fb2215036f0f   None    Ignacio           Papa
# 364  59200686-dd45-4f09-8d8a-fc5fad0417db   None     Matias       Robinson
# 365  97c2dbb4-52de-4607-b3cd-fea726603b3d   None    Casalis       Santiago
#
#              dateOfBirth externalId beingMergedWithProfileId  \
# 0    2007-02-02T00:00:00                                None
# 1    2007-10-04T00:00:00       None                     None
# 2    2007-01-14T00:00:00                                None
# 3    2007-01-09T00:00:00                                None
# 4    2010-05-30T00:00:00   49626725                     None
# ..                   ...        ...                      ...
# 361  2005-01-09T00:00:00       None                     None
# 362  1982-06-08T00:00:00       None                     None
# 363  2005-01-04T00:00:00       None                     None
# 364  2005-01-05T00:00:00       None                     None
# 365  1982-02-02T00:00:00       None                     None
#
#     beingMergedWithProfileExpiryDateUtc                             tenant_id  \
# 0                                  None  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 1                                  None  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 2                                  None  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 3                                  None  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 4                                  None  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# ..                                  ...                                   ...
# 361                                None  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 362                                None  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 363                                None  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 364                                None  f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 365                                None  f1185650-fb79-44a0-8b4b-b2bf82d28c83
#
#                                   groupId         groupName  \
# 0    35a2a19b-f8ea-4963-92b4-98565cf1e030         Inactivos
# 1    35a2a19b-f8ea-4963-92b4-98565cf1e030         Inactivos
# 2    35a2a19b-f8ea-4963-92b4-98565cf1e030         Inactivos
# 3    35a2a19b-f8ea-4963-92b4-98565cf1e030         Inactivos
# 4    31edcc44-ec7e-4ed3-adeb-74e1e803228e          M15 2025
# ..                                    ...               ...
# 361  a1ecef8c-d185-4e45-951c-b6540e390eef  Plantel Superior
# 362  a1ecef8c-d185-4e45-951c-b6540e390eef  Plantel Superior
# 363  a1ecef8c-d185-4e45-951c-b6540e390eef  Plantel Superior
# 364  a1ecef8c-d185-4e45-951c-b6540e390eef  Plantel Superior
# 365  a1ecef8c-d185-4e45-951c-b6540e390eef  Plantel Superior
#
#                                categoryId categoryName
# 0    0e7bfdff-aabb-4efa-ad13-ecb419e0beef         CBMM
# 1    0e7bfdff-aabb-4efa-ad13-ecb419e0beef         CBMM
# 2    0e7bfdff-aabb-4efa-ad13-ecb419e0beef         CBMM
# 3    0e7bfdff-aabb-4efa-ad13-ecb419e0beef         CBMM
# 4    0e7bfdff-aabb-4efa-ad13-ecb419e0beef         CBMM
# ..                                    ...          ...
# 361  0e7bfdff-aabb-4efa-ad13-ecb419e0beef         CBMM
# 362  0e7bfdff-aabb-4efa-ad13-ecb419e0beef         CBMM
# 363  0e7bfdff-aabb-4efa-ad13-ecb419e0beef         CBMM
# 364  0e7bfdff-aabb-4efa-ad13-ecb419e0beef         CBMM
# 365  0e7bfdff-aabb-4efa-ad13-ecb419e0beef         CBMM
#
# [366 rows x 13 columns]

# %%
df_all_profiles[df_all_profiles['familyName']=='SALDAÑA']
# Out:
#                                 profileId syncId givenName familyName  \
# 156  1d4ec7c4-68b1-49f5-92ae-620c89d0032a   None  PATRICIO    SALDAÑA
#
#              dateOfBirth externalId beingMergedWithProfileId  \
# 156  2007-02-03T00:00:00       None                     None
#
#     beingMergedWithProfileExpiryDateUtc                             tenant_id  \
# 156                                None  f1185650-fb79-44a0-8b4b-b2bf82d28c83
#
#                                   groupId groupName  \
# 156  69db9f0b-106b-4b5a-97b8-0a283a488e10  M19 2025
#
#                                categoryId categoryName
# 156  0e7bfdff-aabb-4efa-ad13-ecb419e0beef         CBMM

# %% [markdown]
# # Esta ejecucion al no tener paginacion solo me trae los 50 primeros

# %%
#token, tenant_id, FECHA_DESDE,

base_url = "https://prd-use-api-externalnordbord.valdperformance.com"
    
endpoint = "/tests/v2"
params = {
    "tenantId": tenant_id,
    "modifiedFromUtc": FECHA_DESDE
}

headers = {
    "Authorization": f"Bearer {token}"
}


print(f"🔄 Solicitando datos NordBord para tenant {tenant_id}...")
response = requests.get(f"{base_url}{endpoint}", params=params, headers=headers)

if response.status_code == 200:
    print(f"✅ Datos obtenidos correctamente")
    datos = response.json()

    if isinstance(datos, dict) and 'items' in datos:
        df = pd.DataFrame(datos['items'])
    elif isinstance(datos, list):
                df = pd.DataFrame(datos)
    else:
        df = pd.DataFrame([datos])
expanded_df = pd.json_normalize(df['tests'].iloc[0])
print(len(expanded_df))
# Out:
# 🔄 Solicitando datos NordBord para tenant f1185650-fb79-44a0-8b4b-b2bf82d28c83...
# ✅ Datos obtenidos correctamente
# 50

# %% [markdown]
# # Esta ejecucion tiene paginacion
#
# ### extrae desde el 01-01-2023 23 paginas trayendo 1032 test pero no encuentra mas registros despues de 12-05-2025 y eso no es verdad porque en plataforma el jugador SALDAÑA tiene mas test por ejemplo el dia 17-07-2025
#
#
# 📄 Procesando página 23 (desde: 2025-05-13T23:08:49.165Z)
#
# ✅ Código 204 - No hay más registros para obtener
#
# 🎉 Proceso completado: 1032 registros totales obtenidos en 23 páginas

# %%
import requests
import pandas as pd
from datetime import datetime

def get_forcedecks_complete(token, tenant_id, fecha_desde, profile_id=None):
    """
    Obtiene TODOS los datos de NordBord usando la paginación correcta del endpoint /tests/v2
    """
    base_url = "https://prd-use-api-extforcedecks.valdperformance.com"
    endpoint = "/tests"
    
    headers = {
        "Authorization": f"Bearer {token}"
    }
    
    all_tests = []  # Cambiado para ser más específico
    current_modified_from = fecha_desde
    page_count = 0
    
    print(f"🔄 Iniciando obtención completa de datos ForceDecks para tenant {tenant_id}...")
    
    while True:
        page_count += 1
        print(f"📄 Procesando página {page_count} (desde: {current_modified_from})")
        
        params = {
            "tenantId": tenant_id,
            "modifiedFromUtc": current_modified_from
        }
        
        if profile_id:
            params["profileId"] = profile_id
        
        try:
            response = requests.get(f"{base_url}{endpoint}", params=params, headers=headers)
            
            if response.status_code == 200:
                datos = response.json()
                
                # Determinar la estructura de los datos
                if isinstance(datos, list):
                    current_batch = datos
                elif isinstance(datos, dict):
                    # Buscar diferentes posibles keys
                    if 'tests' in datos:
                        current_batch = datos['tests']
                    elif 'items' in datos:
                        current_batch = datos['items']
                    elif 'data' in datos:
                        current_batch = datos['data']
                    else:
                        # Si es un dict sin keys conocidas, tratarlo como un solo elemento
                        current_batch = [datos]
                else:
                    current_batch = [datos] if datos else []
                
                if not current_batch:
                    print("✅ No hay más datos en esta respuesta")
                    break
                
                print(f"📊 Obtenidos {len(current_batch)} registros en esta página")
                
                # Agregar datos a la lista principal
                all_tests.extend(current_batch)
                
                # CLAVE: Buscar el campo de fecha de modificación para paginación
                last_record = current_batch[-1]
                next_modified_date = None
                
                # Buscar diferentes posibles nombres para el campo de fecha
                possible_date_fields = ['modifiedDateUtc', 'modifiedDate', 'lastModified', 
                                      'updatedAt', 'dateModified', 'modified']
                
                for field in possible_date_fields:
                    if field in last_record:
                        next_modified_date = last_record[field]
                        print(f"🔄 Encontrado campo '{field}': {next_modified_date}")
                        break
                
                if next_modified_date:
                    # Verificar si la fecha es la misma que la anterior (bucle infinito)
                    if next_modified_date == current_modified_from:
                        print("⚠️ Detectado bucle infinito: misma fecha de modificación")
                        print("🔄 Agregando 1 milisegundo para avanzar...")
                        
                        # Convertir a datetime, agregar 1 milisegundo, y volver a string
                        from datetime import datetime, timedelta
                        try:
                            dt = datetime.fromisoformat(next_modified_date.replace('Z', '+00:00'))
                            dt_next = dt + timedelta(milliseconds=1)
                            current_modified_from = dt_next.strftime('%Y-%m-%dT%H:%M:%S.%f')[:-3] + 'Z'
                            print(f"🔄 Nueva fecha: {current_modified_from}")
                        except Exception as e:
                            print(f"❌ Error al procesar fecha: {e}")
                            break
                    else:
                        current_modified_from = next_modified_date
                        print(f"🔄 Siguiente página desde: {current_modified_from}")
                else:
                    print("⚠️ No se encontró campo de fecha de modificación en el último registro")
                    print(f"⚠️ Campos disponibles: {list(last_record.keys())}")
                    break
                
                # Protección adicional contra bucles infinitos
                if page_count > 1000:  # Máximo 1000 páginas
                    print("⚠️ Alcanzado límite máximo de páginas (1000). Deteniendo...")
                    break
                
            elif response.status_code == 204:
                print("✅ Código 204 - No hay más registros para obtener")
                break
                
            else:
                print(f"❌ Error {response.status_code}: {response.text}")
                break
                
        except Exception as e:
            print(f"❌ Error en la solicitud: {str(e)}")
            break
    
    # Convertir a DataFrame
    if all_tests:
        df = pd.DataFrame(all_tests)
        
        # Convertir columnas de fecha (sin el warning)
        date_columns = [col for col in df.columns 
                       if 'date' in col.lower() or 'time' in col.lower()]
        for col in date_columns:
            try:
                df[col] = pd.to_datetime(df[col])
            except:
                pass  # Si no se puede convertir, mantener el formato original
        
        # Añadir información del tenant
        df['tenant_id'] = tenant_id
        
        print(f"🎉 Proceso completado: {len(df)} registros totales obtenidos en {page_count} páginas")
        return df
    else:
        print("⚠️ No se obtuvieron datos")
        return pd.DataFrame()

# %%
df_forcedecks = get_forcedecks_complete(token, tenant_id, FECHA_DESDE)
# Out:
# 🔄 Iniciando obtención completa de datos ForceDecks para tenant f1185650-fb79-44a0-8b4b-b2bf82d28c83...
# 📄 Procesando página 1 (desde: 2023-01-01T00:00:00.000Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-02-09T18:49:26.385Z
# 🔄 Siguiente página desde: 2023-02-09T18:49:26.385Z
# 📄 Procesando página 2 (desde: 2023-02-09T18:49:26.385Z)
# 📊 Obtenidos 51 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-02-14T18:13:46.201Z
# 🔄 Siguiente página desde: 2023-02-14T18:13:46.201Z
# 📄 Procesando página 3 (desde: 2023-02-14T18:13:46.201Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-03-13T17:13:05.878Z
# 🔄 Siguiente página desde: 2023-03-13T17:13:05.878Z
# 📄 Procesando página 4 (desde: 2023-03-13T17:13:05.878Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-03-13T23:12:35.636Z
# 🔄 Siguiente página desde: 2023-03-13T23:12:35.636Z
# 📄 Procesando página 5 (desde: 2023-03-13T23:12:35.636Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-03-16T22:51:42.893Z
# 🔄 Siguiente página desde: 2023-03-16T22:51:42.893Z
# 📄 Procesando página 6 (desde: 2023-03-16T22:51:42.893Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-03-16T23:23:42.277Z
# 🔄 Siguiente página desde: 2023-03-16T23:23:42.277Z
# 📄 Procesando página 7 (desde: 2023-03-16T23:23:42.277Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-03-31T15:52:19.516Z
# 🔄 Siguiente página desde: 2023-03-31T15:52:19.516Z
# 📄 Procesando página 8 (desde: 2023-03-31T15:52:19.516Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-05-19T19:26:27.123Z
# 🔄 Siguiente página desde: 2023-05-19T19:26:27.123Z
# 📄 Procesando página 9 (desde: 2023-05-19T19:26:27.123Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-05-31T12:53:25.327Z
# 🔄 Siguiente página desde: 2023-05-31T12:53:25.327Z
# 📄 Procesando página 10 (desde: 2023-05-31T12:53:25.327Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-06-12T12:50:12.067Z
# 🔄 Siguiente página desde: 2023-06-12T12:50:12.067Z
# 📄 Procesando página 11 (desde: 2023-06-12T12:50:12.067Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-06-12T13:20:44.278Z
# 🔄 Siguiente página desde: 2023-06-12T13:20:44.278Z
# 📄 Procesando página 12 (desde: 2023-06-12T13:20:44.278Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-06-16T18:50:28.131Z
# 🔄 Siguiente página desde: 2023-06-16T18:50:28.131Z
# 📄 Procesando página 13 (desde: 2023-06-16T18:50:28.131Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-06-23T12:47:44.684Z
# 🔄 Siguiente página desde: 2023-06-23T12:47:44.684Z
# 📄 Procesando página 14 (desde: 2023-06-23T12:47:44.684Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-06-29T16:40:11.016Z
# 🔄 Siguiente página desde: 2023-06-29T16:40:11.016Z
# 📄 Procesando página 15 (desde: 2023-06-29T16:40:11.016Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-07-12T11:46:58.710Z
# 🔄 Siguiente página desde: 2023-07-12T11:46:58.710Z
# 📄 Procesando página 16 (desde: 2023-07-12T11:46:58.710Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-07-14T12:04:59.058Z
# 🔄 Siguiente página desde: 2023-07-14T12:04:59.058Z
# 📄 Procesando página 17 (desde: 2023-07-14T12:04:59.058Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-07-14T13:20:05.724Z
# 🔄 Siguiente página desde: 2023-07-14T13:20:05.724Z
# 📄 Procesando página 18 (desde: 2023-07-14T13:20:05.724Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-07-14T19:16:37.725Z
# 🔄 Siguiente página desde: 2023-07-14T19:16:37.725Z
# 📄 Procesando página 19 (desde: 2023-07-14T19:16:37.725Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-07-24T12:15:10.905Z
# 🔄 Siguiente página desde: 2023-07-24T12:15:10.905Z
# 📄 Procesando página 20 (desde: 2023-07-24T12:15:10.905Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-07-25T11:54:26.894Z
# 🔄 Siguiente página desde: 2023-07-25T11:54:26.894Z
# 📄 Procesando página 21 (desde: 2023-07-25T11:54:26.894Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-07-25T12:46:25.640Z
# 🔄 Siguiente página desde: 2023-07-25T12:46:25.640Z
# 📄 Procesando página 22 (desde: 2023-07-25T12:46:25.640Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-07-25T14:17:23.251Z
# 🔄 Siguiente página desde: 2023-07-25T14:17:23.251Z
# 📄 Procesando página 23 (desde: 2023-07-25T14:17:23.251Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-08-01T12:26:43.384Z
# 🔄 Siguiente página desde: 2023-08-01T12:26:43.384Z
# 📄 Procesando página 24 (desde: 2023-08-01T12:26:43.384Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-08-01T13:22:33.154Z
# 🔄 Siguiente página desde: 2023-08-01T13:22:33.154Z
# 📄 Procesando página 25 (desde: 2023-08-01T13:22:33.154Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-08-07T16:04:09.102Z
# 🔄 Siguiente página desde: 2023-08-07T16:04:09.102Z
# 📄 Procesando página 26 (desde: 2023-08-07T16:04:09.102Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-08-07T16:06:10.981Z
# 🔄 Siguiente página desde: 2023-08-07T16:06:10.981Z
# 📄 Procesando página 27 (desde: 2023-08-07T16:06:10.981Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-08-08T11:50:22.292Z
# 🔄 Siguiente página desde: 2023-08-08T11:50:22.292Z
# 📄 Procesando página 28 (desde: 2023-08-08T11:50:22.292Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-08-08T13:30:44.082Z
# 🔄 Siguiente página desde: 2023-08-08T13:30:44.082Z
# 📄 Procesando página 29 (desde: 2023-08-08T13:30:44.082Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-11-01T19:54:57.459Z
# 🔄 Siguiente página desde: 2023-11-01T19:54:57.459Z
# 📄 Procesando página 30 (desde: 2023-11-01T19:54:57.459Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-11-13T12:46:52.949Z
# 🔄 Siguiente página desde: 2023-11-13T12:46:52.949Z
# 📄 Procesando página 31 (desde: 2023-11-13T12:46:52.949Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-11-13T14:00:13.701Z
# 🔄 Siguiente página desde: 2023-11-13T14:00:13.701Z
# 📄 Procesando página 32 (desde: 2023-11-13T14:00:13.701Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-11-14T12:26:18.353Z
# 🔄 Siguiente página desde: 2023-11-14T12:26:18.353Z
# 📄 Procesando página 33 (desde: 2023-11-14T12:26:18.353Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-11-14T13:40:27.268Z
# 🔄 Siguiente página desde: 2023-11-14T13:40:27.268Z
# 📄 Procesando página 34 (desde: 2023-11-14T13:40:27.268Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-11-28T12:11:20.361Z
# 🔄 Siguiente página desde: 2023-11-28T12:11:20.361Z
# 📄 Procesando página 35 (desde: 2023-11-28T12:11:20.361Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-11-28T13:04:30.215Z
# 🔄 Siguiente página desde: 2023-11-28T13:04:30.215Z
# 📄 Procesando página 36 (desde: 2023-11-28T13:04:30.215Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-12-20T00:16:49.447Z
# 🔄 Siguiente página desde: 2023-12-20T00:16:49.447Z
# 📄 Procesando página 37 (desde: 2023-12-20T00:16:49.447Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2024-01-09T14:41:48.945Z
# 🔄 Siguiente página desde: 2024-01-09T14:41:48.945Z
# 📄 Procesando página 38 (desde: 2024-01-09T14:41:48.945Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2024-02-06T01:04:24.117Z
# 🔄 Siguiente página desde: 2024-02-06T01:04:24.117Z
# 📄 Procesando página 39 (desde: 2024-02-06T01:04:24.117Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2024-03-07T21:32:48.630Z
# 🔄 Siguiente página desde: 2024-03-07T21:32:48.630Z
# 📄 Procesando página 40 (desde: 2024-03-07T21:32:48.630Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2024-03-14T22:25:04.586Z
# 🔄 Siguiente página desde: 2024-03-14T22:25:04.586Z
# 📄 Procesando página 41 (desde: 2024-03-14T22:25:04.586Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2024-04-24T21:21:55.785Z
# 🔄 Siguiente página desde: 2024-04-24T21:21:55.785Z
# 📄 Procesando página 42 (desde: 2024-04-24T21:21:55.785Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2024-04-26T21:03:16.857Z
# 🔄 Siguiente página desde: 2024-04-26T21:03:16.857Z
# 📄 Procesando página 43 (desde: 2024-04-26T21:03:16.857Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2024-04-26T22:56:11.079Z
# 🔄 Siguiente página desde: 2024-04-26T22:56:11.079Z
# 📄 Procesando página 44 (desde: 2024-04-26T22:56:11.079Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2024-05-15T12:44:28.530Z
# 🔄 Siguiente página desde: 2024-05-15T12:44:28.530Z
# 📄 Procesando página 45 (desde: 2024-05-15T12:44:28.530Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2024-06-05T21:21:33.183Z
# 🔄 Siguiente página desde: 2024-06-05T21:21:33.183Z
# 📄 Procesando página 46 (desde: 2024-06-05T21:21:33.183Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2024-06-07T21:09:39.050Z
# 🔄 Siguiente página desde: 2024-06-07T21:09:39.050Z
# 📄 Procesando página 47 (desde: 2024-06-07T21:09:39.050Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2024-06-19T12:56:23.091Z
# 🔄 Siguiente página desde: 2024-06-19T12:56:23.091Z
# 📄 Procesando página 48 (desde: 2024-06-19T12:56:23.091Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2024-07-01T12:34:25.788Z
# 🔄 Siguiente página desde: 2024-07-01T12:34:25.788Z
# 📄 Procesando página 49 (desde: 2024-07-01T12:34:25.788Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2024-07-08T12:40:57.824Z
# 🔄 Siguiente página desde: 2024-07-08T12:40:57.824Z
# 📄 Procesando página 50 (desde: 2024-07-08T12:40:57.824Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2024-07-10T23:57:29.905Z
# 🔄 Siguiente página desde: 2024-07-10T23:57:29.905Z
# 📄 Procesando página 51 (desde: 2024-07-10T23:57:29.905Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2024-07-19T15:25:54.850Z
# 🔄 Siguiente página desde: 2024-07-19T15:25:54.850Z
# 📄 Procesando página 52 (desde: 2024-07-19T15:25:54.850Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2024-07-19T15:52:49.370Z
# 🔄 Siguiente página desde: 2024-07-19T15:52:49.370Z
# 📄 Procesando página 53 (desde: 2024-07-19T15:52:49.370Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2024-07-22T17:00:59.255Z
# 🔄 Siguiente página desde: 2024-07-22T17:00:59.255Z
# 📄 Procesando página 54 (desde: 2024-07-22T17:00:59.255Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2024-07-26T19:54:59.429Z
# 🔄 Siguiente página desde: 2024-07-26T19:54:59.429Z
# 📄 Procesando página 55 (desde: 2024-07-26T19:54:59.429Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2024-07-30T22:29:54.909Z
# 🔄 Siguiente página desde: 2024-07-30T22:29:54.909Z
# 📄 Procesando página 56 (desde: 2024-07-30T22:29:54.909Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2024-08-01T15:17:03.513Z
# 🔄 Siguiente página desde: 2024-08-01T15:17:03.513Z
# 📄 Procesando página 57 (desde: 2024-08-01T15:17:03.513Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2024-08-13T12:40:31.436Z
# 🔄 Siguiente página desde: 2024-08-13T12:40:31.436Z
# 📄 Procesando página 58 (desde: 2024-08-13T12:40:31.436Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2024-09-28T20:56:20.190Z
# 🔄 Siguiente página desde: 2024-09-28T20:56:20.190Z
# 📄 Procesando página 59 (desde: 2024-09-28T20:56:20.190Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2025-02-03T23:13:38.160Z
# 🔄 Siguiente página desde: 2025-02-03T23:13:38.160Z
# 📄 Procesando página 60 (desde: 2025-02-03T23:13:38.160Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2025-03-06T22:21:10.265Z
# 🔄 Siguiente página desde: 2025-03-06T22:21:10.265Z
# 📄 Procesando página 61 (desde: 2025-03-06T22:21:10.265Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2025-03-06T23:06:01.282Z
# 🔄 Siguiente página desde: 2025-03-06T23:06:01.282Z
# 📄 Procesando página 62 (desde: 2025-03-06T23:06:01.282Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2025-03-14T11:35:26.011Z
# 🔄 Siguiente página desde: 2025-03-14T11:35:26.011Z
# 📄 Procesando página 63 (desde: 2025-03-14T11:35:26.011Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2025-03-14T16:28:17.157Z
# 🔄 Siguiente página desde: 2025-03-14T16:28:17.157Z
# 📄 Procesando página 64 (desde: 2025-03-14T16:28:17.157Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2025-03-21T10:47:23.366Z
# 🔄 Siguiente página desde: 2025-03-21T10:47:23.366Z
# 📄 Procesando página 65 (desde: 2025-03-21T10:47:23.366Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2025-04-15T23:42:17.547Z
# 🔄 Siguiente página desde: 2025-04-15T23:42:17.547Z
# 📄 Procesando página 66 (desde: 2025-04-15T23:42:17.547Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2025-05-14T11:12:02.284Z
# 🔄 Siguiente página desde: 2025-05-14T11:12:02.284Z
# 📄 Procesando página 67 (desde: 2025-05-14T11:12:02.284Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2025-06-12T12:41:23.894Z
# 🔄 Siguiente página desde: 2025-06-12T12:41:23.894Z
# 📄 Procesando página 68 (desde: 2025-06-12T12:41:23.894Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2025-07-17T22:22:44.047Z
# 🔄 Siguiente página desde: 2025-07-17T22:22:44.047Z
# 📄 Procesando página 69 (desde: 2025-07-17T22:22:44.047Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2025-07-22T22:40:47.210Z
# 🔄 Siguiente página desde: 2025-07-22T22:40:47.210Z
# 📄 Procesando página 70 (desde: 2025-07-22T22:40:47.210Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2025-07-29T00:03:29.198Z
# 🔄 Siguiente página desde: 2025-07-29T00:03:29.198Z
# 📄 Procesando página 71 (desde: 2025-07-29T00:03:29.198Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2025-08-05T22:10:57.770Z
# 🔄 Siguiente página desde: 2025-08-05T22:10:57.770Z
# 📄 Procesando página 72 (desde: 2025-08-05T22:10:57.770Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2025-08-22T13:05:37.921Z
# 🔄 Siguiente página desde: 2025-08-22T13:05:37.921Z
# 📄 Procesando página 73 (desde: 2025-08-22T13:05:37.921Z)
# 📊 Obtenidos 34 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2025-10-18T14:33:48.190Z
# 🔄 Siguiente página desde: 2025-10-18T14:33:48.190Z
# 📄 Procesando página 74 (desde: 2025-10-18T14:33:48.190Z)
# ✅ Código 204 - No hay más registros para obtener
# 🎉 Proceso completado: 3635 registros totales obtenidos en 74 páginas
# /var/folders/k1/j4nrrlzs2t93tp860tb51m9m0000gn/T/ipykernel_18299/1692729950.py:130: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# /var/folders/k1/j4nrrlzs2t93tp860tb51m9m0000gn/T/ipykernel_18299/1692729950.py:130: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])

# %%
len(df_forcedecks)
# Out:
# 3635

# %%
def get_dynamo_complete(token, tenant_id, fecha_desde, profile_id=None):
    """
    Obtiene TODOS los datos de Dynamo usando la paginación correcta del endpoint /tests
    """
    base_url = "https://prd-use-api-extdynamo.valdperformance.com"
    endpoint = "/tests"
    
    headers = {
        "Authorization": f"Bearer {token}"
    }
    
    all_tests = []  # Cambiado para ser más específico
    current_modified_from = fecha_desde
    page_count = 0
    
    print(f"🔄 Iniciando obtención completa de datos Dynamo para tenant {tenant_id}...")
    
    while True:
        page_count += 1
        print(f"📄 Procesando página {page_count} (desde: {current_modified_from})")
        
        params = {
            "tenantId": tenant_id,
            "modifiedFromUtc": current_modified_from
        }
        
        if profile_id:
            params["profileId"] = profile_id
        
        try:
            response = requests.get(f"{base_url}{endpoint}", params=params, headers=headers)
            
            if response.status_code == 200:
                datos = response.json()
                
                # Determinar la estructura de los datos
                if isinstance(datos, list):
                    current_batch = datos
                elif isinstance(datos, dict):
                    # Buscar diferentes posibles keys
                    if 'tests' in datos:
                        current_batch = datos['tests']
                    elif 'items' in datos:
                        current_batch = datos['items']
                    elif 'data' in datos:
                        current_batch = datos['data']
                    else:
                        # Si es un dict sin keys conocidas, tratarlo como un solo elemento
                        current_batch = [datos]
                else:
                    current_batch = [datos] if datos else []
                
                if not current_batch:
                    print("✅ No hay más datos en esta respuesta")
                    break
                
                print(f"📊 Obtenidos {len(current_batch)} registros en esta página")
                
                # Agregar datos a la lista principal
                all_tests.extend(current_batch)
                
                # CLAVE: Buscar el campo de fecha de modificación para paginación
                last_record = current_batch[-1]
                next_modified_date = None
                
                # Buscar diferentes posibles nombres para el campo de fecha
                possible_date_fields = ['modifiedDateUtc', 'modifiedDate', 'lastModified', 
                                      'updatedAt', 'dateModified', 'modified']
                
                for field in possible_date_fields:
                    if field in last_record:
                        next_modified_date = last_record[field]
                        print(f"🔄 Encontrado campo '{field}': {next_modified_date}")
                        break
                
                if next_modified_date:
                    # Verificar si la fecha es la misma que la anterior (bucle infinito)
                    if next_modified_date == current_modified_from:
                        print("⚠️ Detectado bucle infinito: misma fecha de modificación")
                        print("🔄 Agregando 1 milisegundo para avanzar...")
                        
                        # Convertir a datetime, agregar 1 milisegundo, y volver a string
                        from datetime import datetime, timedelta
                        try:
                            dt = datetime.fromisoformat(next_modified_date.replace('Z', '+00:00'))
                            dt_next = dt + timedelta(milliseconds=1)
                            current_modified_from = dt_next.strftime('%Y-%m-%dT%H:%M:%S.%f')[:-3] + 'Z'
                            print(f"🔄 Nueva fecha: {current_modified_from}")
                        except Exception as e:
                            print(f"❌ Error al procesar fecha: {e}")
                            break
                    else:
                        current_modified_from = next_modified_date
                        print(f"🔄 Siguiente página desde: {current_modified_from}")
                else:
                    print("⚠️ No se encontró campo de fecha de modificación en el último registro")
                    print(f"⚠️ Campos disponibles: {list(last_record.keys())}")
                    break
                
                # Protección adicional contra bucles infinitos
                if page_count > 1000:  # Máximo 1000 páginas
                    print("⚠️ Alcanzado límite máximo de páginas (1000). Deteniendo...")
                    break
                
            elif response.status_code == 204:
                print("✅ Código 204 - No hay más registros para obtener")
                break
                
            else:
                print(f"❌ Error {response.status_code}: {response.text}")
                break
                
        except Exception as e:
            print(f"❌ Error en la solicitud: {str(e)}")
            break
    
    # Convertir a DataFrame
    if all_tests:
        df = pd.DataFrame(all_tests)
        
        # Convertir columnas de fecha (sin el warning)
        date_columns = [col for col in df.columns 
                       if 'date' in col.lower() or 'time' in col.lower()]
        for col in date_columns:
            try:
                df[col] = pd.to_datetime(df[col])
            except:
                pass  # Si no se puede convertir, mantener el formato original
        
        # Añadir información del tenant
        df['tenant_id'] = tenant_id
        
        print(f"🎉 Proceso completado: {len(df)} registros totales obtenidos en {page_count} páginas")
        return df
    else:
        print("⚠️ No se obtuvieron datos")
        return pd.DataFrame()

# %%
df_dynamo = get_dynamo_complete(token, tenant_id, FECHA_DESDE)
# Out:
# 🔄 Iniciando obtención completa de datos Dynamo para tenant f1185650-fb79-44a0-8b4b-b2bf82d28c83...
# 📄 Procesando página 1 (desde: 2023-01-01T00:00:00.000Z)
# ❌ Error 404:
# ⚠️ No se obtuvieron datos

# %%
df_nordbord = get_nordbord_complete(token, tenant_id, FECHA_DESDE)
# Out:
# 🔄 Iniciando obtención completa de datos NordBord para tenant f1185650-fb79-44a0-8b4b-b2bf82d28c83...
# 📄 Procesando página 1 (desde: 2023-01-01T00:00:00.000Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-02-10T23:36:42.354Z
# 🔄 Siguiente página desde: 2023-02-10T23:36:42.354Z
# 📄 Procesando página 2 (desde: 2023-02-10T23:36:42.354Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-03-06T23:47:11.341Z
# 🔄 Siguiente página desde: 2023-03-06T23:47:11.341Z
# 📄 Procesando página 3 (desde: 2023-03-06T23:47:11.341Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-03-28T23:34:44.151Z
# 🔄 Siguiente página desde: 2023-03-28T23:34:44.151Z
# 📄 Procesando página 4 (desde: 2023-03-28T23:34:44.151Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-04-19T12:00:32.307Z
# 🔄 Siguiente página desde: 2023-04-19T12:00:32.307Z
# 📄 Procesando página 5 (desde: 2023-04-19T12:00:32.307Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-05-15T22:51:25.885Z
# 🔄 Siguiente página desde: 2023-05-15T22:51:25.885Z
# 📄 Procesando página 6 (desde: 2023-05-15T22:51:25.885Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-08-07T15:02:47.528Z
# 🔄 Siguiente página desde: 2023-08-07T15:02:47.528Z
# 📄 Procesando página 7 (desde: 2023-08-07T15:02:47.528Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-08-24T16:06:39.234Z
# 🔄 Siguiente página desde: 2023-08-24T16:06:39.234Z
# 📄 Procesando página 8 (desde: 2023-08-24T16:06:39.234Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-11-13T13:20:26.593Z
# 🔄 Siguiente página desde: 2023-11-13T13:20:26.593Z
# 📄 Procesando página 9 (desde: 2023-11-13T13:20:26.593Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-11-14T12:33:42.025Z
# 🔄 Siguiente página desde: 2023-11-14T12:33:42.025Z
# 📄 Procesando página 10 (desde: 2023-11-14T12:33:42.025Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-11-15T12:07:59.254Z
# 🔄 Siguiente página desde: 2023-11-15T12:07:59.254Z
# 📄 Procesando página 11 (desde: 2023-11-15T12:07:59.254Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-11-29T11:26:19.204Z
# 🔄 Siguiente página desde: 2023-11-29T11:26:19.204Z
# 📄 Procesando página 12 (desde: 2023-11-29T11:26:19.204Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-12-01T11:29:11.023Z
# 🔄 Siguiente página desde: 2023-12-01T11:29:11.023Z
# 📄 Procesando página 13 (desde: 2023-12-01T11:29:11.023Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2023-12-21T22:36:15.694Z
# 🔄 Siguiente página desde: 2023-12-21T22:36:15.694Z
# 📄 Procesando página 14 (desde: 2023-12-21T22:36:15.694Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2024-01-15T23:35:34.306Z
# 🔄 Siguiente página desde: 2024-01-15T23:35:34.306Z
# 📄 Procesando página 15 (desde: 2024-01-15T23:35:34.306Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2024-04-26T22:48:09.621Z
# 🔄 Siguiente página desde: 2024-04-26T22:48:09.621Z
# 📄 Procesando página 16 (desde: 2024-04-26T22:48:09.621Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2024-06-07T21:24:16.482Z
# 🔄 Siguiente página desde: 2024-06-07T21:24:16.482Z
# 📄 Procesando página 17 (desde: 2024-06-07T21:24:16.482Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2024-07-01T13:01:24.618Z
# 🔄 Siguiente página desde: 2024-07-01T13:01:24.618Z
# 📄 Procesando página 18 (desde: 2024-07-01T13:01:24.618Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2024-12-05T11:58:32.120Z
# 🔄 Siguiente página desde: 2024-12-05T11:58:32.120Z
# 📄 Procesando página 19 (desde: 2024-12-05T11:58:32.120Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2025-01-28T23:54:04.340Z
# 🔄 Siguiente página desde: 2025-01-28T23:54:04.340Z
# 📄 Procesando página 20 (desde: 2025-01-28T23:54:04.340Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2025-04-15T22:48:29.653Z
# 🔄 Siguiente página desde: 2025-04-15T22:48:29.653Z
# 📄 Procesando página 21 (desde: 2025-04-15T22:48:29.653Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2025-07-17T22:32:47.864Z
# 🔄 Siguiente página desde: 2025-07-17T22:32:47.864Z
# 📄 Procesando página 22 (desde: 2025-07-17T22:32:47.864Z)
# 📊 Obtenidos 50 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2025-07-28T23:25:26.572Z
# 🔄 Siguiente página desde: 2025-07-28T23:25:26.572Z
# 📄 Procesando página 23 (desde: 2025-07-28T23:25:26.572Z)
# 📊 Obtenidos 16 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2025-08-22T12:46:59.175Z
# 🔄 Siguiente página desde: 2025-08-22T12:46:59.175Z
# 📄 Procesando página 24 (desde: 2025-08-22T12:46:59.175Z)
# 📊 Obtenidos 1 registros en esta página
# 🔄 Encontrado campo 'modifiedDateUtc': 2025-08-22T12:46:59.175Z
# ⚠️ Detectado bucle infinito: misma fecha de modificación
# 🔄 Agregando 1 milisegundo para avanzar...
# 🔄 Nueva fecha: 2025-08-22T12:46:59.176Z
# 📄 Procesando página 25 (desde: 2025-08-22T12:46:59.176Z)
# ✅ Código 204 - No hay más registros para obtener
# 🎉 Proceso completado: 1117 registros totales obtenidos en 25 páginas

# %%
df_all_profiles[df_all_profiles['familyName']=='SALDAÑA']
# Out:
#                                 profileId syncId givenName familyName  \
# 150  1d4ec7c4-68b1-49f5-92ae-620c89d0032a   None  PATRICIO    SALDAÑA
#
#              dateOfBirth externalId                             tenant_id  \
# 150  2007-02-03T00:00:00             f1185650-fb79-44a0-8b4b-b2bf82d28c83
#
#                                   groupId groupName  \
# 150  69db9f0b-106b-4b5a-97b8-0a283a488e10  M19 2025
#
#                                categoryId categoryName
# 150  0e7bfdff-aabb-4efa-ad13-ecb419e0beef         CBMM

# %%
df_all_profiles[df_all_profiles['profileId']=='1d4ec7c4-68b1-49f5-92ae-620c89d0032a']
# Out:
#                                 profileId syncId givenName familyName  \
# 150  1d4ec7c4-68b1-49f5-92ae-620c89d0032a   None  PATRICIO    SALDAÑA
#
#              dateOfBirth externalId                             tenant_id  \
# 150  2007-02-03T00:00:00             f1185650-fb79-44a0-8b4b-b2bf82d28c83
#
#                                   groupId groupName  \
# 150  69db9f0b-106b-4b5a-97b8-0a283a488e10  M19 2025
#
#                                categoryId categoryName
# 150  0e7bfdff-aabb-4efa-ad13-ecb419e0beef         CBMM

# %%
df_nordbord[df_nordbord['profileId']=='c2200d7c-6c9b-469d-98e0-4321d6ba1af0']
# Out:
#                                  profileId  \
# 1110  c2200d7c-6c9b-469d-98e0-4321d6ba1af0
#
#                                     testId                  modifiedDateUtc  \
# 1110  db894d42-a938-40ef-8bfa-256a275f697c 2025-08-05 22:35:54.903000+00:00
#
#                           testDateUtc                            testTypeId  \
# 1110 2025-08-05 22:35:54.680000+00:00  f9755ba4-17cf-4c47-9c3d-a8995905073d
#
#      testTypeName notes         device  leftAvgForce  leftImpulse  ...  \
# 1110    ISO Prone        NordBord-1756         298.0      4076.89  ...
#
#       leftTorque  leftCalibration  leftRepetitions  rightAvgForce  \
# 1110  111.583125              0.0                2          402.0
#
#       rightImpulse  rightMaxForce  rightTorque  rightCalibration  \
# 1110       6336.41          486.0      181.521               0.0
#
#       rightRepetitions                             tenant_id
# 1110                 3  f1185650-fb79-44a0-8b4b-b2bf82d28c83
#
# [1 rows x 21 columns]

# %%
len(df_nordbord)
# Out:
# 1117

# %% [markdown]
# # OTRAS PRUEBAS
#
# ### despues probe con otros filtros de fechas pero siempre trae hasta el 13-05-2025
#
# 📈 Distribución por año:
#
#    2023: 4 tests
#
#    2024: 226 tests
#
#    2025: 119 tests
#
# 📊 Registros obtenidos: 349

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta

def get_nordbord_complete_and_filter(token, tenant_id, test_from_date="2023-01-01", test_to_date=None):
    """
    SOLUCIÓN FINAL: Usa el endpoint que funciona y filtra después por fecha del test
    
    Args:
        token: Token de autorización
        tenant_id: ID del tenant
        test_from_date: Fecha desde cuando se realizaron los tests (ej: "2023-01-01")
        test_to_date: Fecha hasta (opcional)
    """
    
    print(f"🎯 MÉTODO FINAL: Obtener todos los datos disponibles y filtrar")
    print(f"📅 Filtrar tests realizados desde: {test_from_date}")
    
    # La API solo permite datos recientes, así que obtenemos todos los disponibles
    # Usar fecha de modificación que permita obtener el máximo de datos
    modified_from_recent = "2024-01-01T00:00:00.000Z"  # Fecha más reciente que puede funcionar
    
    # Obtener datos usando el endpoint que SÍ funciona
    df = get_nordbord_working_endpoint(token, tenant_id, modified_from_recent)
    
    if df.empty:
        print("⚠️ No se obtuvieron datos del endpoint")
        return df
    
    print(f"📊 Total de registros obtenidos: {len(df)}")
    
    # Inspeccionar columnas de fecha disponibles
    date_columns = [col for col in df.columns if 'date' in col.lower() or 'time' in col.lower()]
    print(f"📅 Columnas de fecha disponibles: {date_columns}")
    
    # Buscar la columna de fecha del test
    test_date_col = None
    
    # Prioridad de búsqueda
    priority_columns = ['testDateUtc', 'testDate', 'dateUtc', 'date']
    
    for col_name in priority_columns:
        if col_name in df.columns:
            test_date_col = col_name
            print(f"✅ Usando columna de fecha del test: '{test_date_col}'")
            break
    
    if not test_date_col:
        # Si no encuentra las prioritarias, usar la primera que no sea 'modified'
        non_modified_dates = [col for col in date_columns if 'modified' not in col.lower()]
        if non_modified_dates:
            test_date_col = non_modified_dates[0]
            print(f"📅 Usando primera columna de fecha no-modificada: '{test_date_col}'")
        else:
            print("⚠️ No se encontró columna adecuada para fecha del test")
            print(f"📋 Columnas disponibles: {list(df.columns)}")
            return df
    
    # Convertir columna de fecha a datetime
    try:
        df[test_date_col] = pd.to_datetime(df[test_date_col])
        print(f"✅ Columna '{test_date_col}' convertida a datetime")
    except Exception as e:
        print(f"❌ Error convirtiendo '{test_date_col}' a datetime: {e}")
        return df
    
    # Mostrar rango de fechas disponibles
    min_date = df[test_date_col].min()
    max_date = df[test_date_col].max()
    print(f"📊 Rango de fechas en los datos: {min_date.strftime('%Y-%m-%d')} a {max_date.strftime('%Y-%m-%d')}")
    
    # Aplicar filtro por fecha del test (con timezone UTC)
    test_from_dt = pd.to_datetime(test_from_date, utc=True)
    print(f"🔍 Filtrando tests realizados desde: {test_from_dt.strftime('%Y-%m-%d')}")
    
    # Aplicar filtro
    filtered_df = df[df[test_date_col] >= test_from_dt].copy()
    
    if test_to_date:
        test_to_dt = pd.to_datetime(test_to_date, utc=True)
        print(f"🔍 Filtrando tests realizados hasta: {test_to_dt.strftime('%Y-%m-%d')}")
        filtered_df = filtered_df[filtered_df[test_date_col] <= test_to_dt]
    
    print(f"🎉 Filtrado completado: {len(filtered_df)} registros de {len(df)} totales")
    
    if len(filtered_df) > 0:
        filtered_min = filtered_df[test_date_col].min()
        filtered_max = filtered_df[test_date_col].max()
        print(f"📊 Rango final: {filtered_min.strftime('%Y-%m-%d')} a {filtered_max.strftime('%Y-%m-%d')}")
        
        # Mostrar distribución por año
        filtered_df['year'] = filtered_df[test_date_col].dt.year
        year_counts = filtered_df['year'].value_counts().sort_index()
        print(f"📈 Distribución por año:")
        for year, count in year_counts.items():
            print(f"   {year}: {count} tests")
        filtered_df = filtered_df.drop('year', axis=1)
    else:
        print("⚠️ No se encontraron tests en el rango de fechas especificado")
    
    return filtered_df


def get_nordbord_working_endpoint(token, tenant_id, fecha_desde, profile_id=None):
    """
    Función que usa el endpoint /tests/v2 que sabemos que funciona
    (Optimizada para obtener TODOS los datos disponibles)
    """
    base_url = "https://prd-use-api-externalnordbord.valdperformance.com"
    endpoint = "/tests/v2"
    
    headers = {"Authorization": f"Bearer {token}"}
    
    all_tests = []
    current_modified_from = fecha_desde
    page_count = 0
    
    print(f"📡 Extrayendo datos desde API NordBord (tenant: {tenant_id})")
    print(f"⏰ Usando modifiedFromUtc: {fecha_desde}")
    
    while True:
        page_count += 1
        
        # Log menos frecuente para no saturar
        if page_count == 1 or page_count % 20 == 0:
            print(f"📄 Página {page_count} - {len(all_tests)} registros acumulados")
        
        params = {
            "tenantId": tenant_id,
            "modifiedFromUtc": current_modified_from
        }
        
        if profile_id:
            params["profileId"] = profile_id
        
        try:
            response = requests.get(f"{base_url}{endpoint}", params=params, headers=headers)
            
            if response.status_code == 200:
                datos = response.json()
                
                # Determinar estructura de datos
                if isinstance(datos, list):
                    current_batch = datos
                elif isinstance(datos, dict):
                    current_batch = datos.get('tests', datos.get('items', datos.get('data', [datos])))
                else:
                    current_batch = [datos] if datos else []
                
                if not current_batch:
                    print("✅ No hay más datos")
                    break
                
                all_tests.extend(current_batch)
                
                # Lógica de paginación anti-bucle infinito
                last_record = current_batch[-1]
                next_modified_date = None
                
                for field in ['modifiedDateUtc', 'modifiedDate', 'lastModified', 'updatedAt']:
                    if field in last_record:
                        next_modified_date = last_record[field]
                        break
                
                if next_modified_date:
                    if next_modified_date == current_modified_from:
                        # Detectado bucle infinito - agregar milisegundo
                        try:
                            dt = datetime.fromisoformat(next_modified_date.replace('Z', '+00:00'))
                            dt_next = dt + timedelta(milliseconds=1)
                            current_modified_from = dt_next.strftime('%Y-%m-%dT%H:%M:%S.%f')[:-3] + 'Z'
                        except Exception as e:
                            print(f"❌ Error procesando fecha: {e}")
                            break
                    else:
                        current_modified_from = next_modified_date
                else:
                    print("⚠️ No se encontró campo de paginación")
                    break
                
                # Límite de seguridad
                if page_count > 3000:
                    print("⚠️ Alcanzado límite máximo de páginas (3000)")
                    break
                
            elif response.status_code == 204:
                print("✅ No hay más registros disponibles")
                break
                
            else:
                print(f"❌ Error HTTP {response.status_code}: {response.text}")
                break
                
        except Exception as e:
            print(f"❌ Error en solicitud: {str(e)}")
            break
    
    # Procesar resultados
    if all_tests:
        df = pd.DataFrame(all_tests)
        
        # Convertir todas las columnas de fecha
        date_columns = [col for col in df.columns if 'date' in col.lower() or 'time' in col.lower()]
        for col in date_columns:
            try:
                df[col] = pd.to_datetime(df[col])
            except:
                pass  # Mantener original si no se puede convertir
        
        df['tenant_id'] = tenant_id
        
        print(f"🎉 Extracción completada: {len(df)} registros en {page_count} páginas")
        return df
    else:
        print("⚠️ No se obtuvieron datos")
        return pd.DataFrame()


def debug_nordbord_structure(token, tenant_id):
    """
    Función de debug para inspeccionar la estructura de datos
    """
    print("🔍 DEBUG: Inspeccionando estructura de datos NordBord")
    
    # Obtener una muestra pequeña con fecha reciente
    recent_date = "2025-01-01T00:00:00.000Z"
    df_sample = get_nordbord_working_endpoint(token, tenant_id, recent_date)
    
    if not df_sample.empty:
        print(f"\n📊 Muestra obtenida: {len(df_sample)} registros")
        print(f"📋 Todas las columnas ({len(df_sample.columns)}):")
        
        for i, col in enumerate(df_sample.columns, 1):
            print(f"  {i:2d}. {col}")
        
        # Mostrar columnas de fecha con ejemplos
        date_cols = [col for col in df_sample.columns if 'date' in col.lower() or 'time' in col.lower()]
        print(f"\n📅 Columnas de fecha ({len(date_cols)}):")
        
        for col in date_cols:
            # Obtener valores únicos (sin NaN)
            unique_values = df_sample[col].dropna().unique()[:3]
            print(f"  - {col}: {list(unique_values)}")
        
        # Mostrar una fila completa como ejemplo
        print(f"\n📋 Ejemplo de un registro:")
        first_row = df_sample.iloc[0]
        for col, value in first_row.items():
            if len(str(value)) < 100:  # Solo valores cortos
                print(f"  {col}: {value}")
        
        return df_sample
    else:
        print("❌ No se pudo obtener muestra para debug")
        return pd.DataFrame()


# FUNCIÓN PRINCIPAL PARA USAR EN TU CÓDIGO
def get_nordbord_final(token, tenant_id, test_from_date="2023-01-01"):
    """
    Función principal para obtener datos NordBord filtrados por fecha del test
    
    Esta es la función que debes usar en lugar de get_nordbord_complete
    """
    print(f"🚀 Iniciando extracción NordBord filtrada por fecha del test")
    
    try:
        df = get_nordbord_complete_and_filter(token, tenant_id, test_from_date)
        
        if df.empty:
            print("🔍 Ejecutando debug para inspeccionar estructura...")
            debug_nordbord_structure(token, tenant_id)
        
        return df
        
    except Exception as e:
        print(f"❌ Error en extracción: {e}")
        print("🔍 Ejecutando debug...")
        debug_nordbord_structure(token, tenant_id)
        return pd.DataFrame()


# PARA USAR EN TU EXTRACTOR.PY:
# Reemplaza:
#   df_nordbord = get_nordbord_complete(token, tenant_id, FECHA_DESDE)
# Por:
#   df_nordbord = get_nordbord_final(token, tenant_id, "2023-01-01")

# %%
df_nordbord_fixed = get_nordbord_final(token, tenant_id, "2023-01-01")
print(f"📊 Registros obtenidos: {len(df_nordbord_fixed)}")
# Out:
# 🚀 Iniciando extracción NordBord filtrada por fecha del test
# 🎯 MÉTODO FINAL: Obtener todos los datos disponibles y filtrar
# 📅 Filtrar tests realizados desde: 2023-01-01
# 📡 Extrayendo datos desde API NordBord (tenant: f1185650-fb79-44a0-8b4b-b2bf82d28c83)
# ⏰ Usando modifiedFromUtc: 2024-01-01T00:00:00.000Z
# 📄 Página 1 - 0 registros acumulados
# ✅ No hay más registros disponibles
# 🎉 Extracción completada: 349 registros en 9 páginas
# 📊 Total de registros obtenidos: 349
# 📅 Columnas de fecha disponibles: ['modifiedDateUtc', 'testDateUtc']
# ✅ Usando columna de fecha del test: 'testDateUtc'
# ✅ Columna 'testDateUtc' convertida a datetime
# 📊 Rango de fechas en los datos: 2023-05-15 a 2025-05-13
# 🔍 Filtrando tests realizados desde: 2023-01-01
# 🎉 Filtrado completado: 349 registros de 349 totales
# 📊 Rango final: 2023-05-15 a 2025-05-13
# 📈 Distribución por año:
#    2023: 4 tests
#    2024: 226 tests
#    2025: 119 tests
# 📊 Registros obtenidos: 349

# %%
len(df_nordbord_fixed)
# Out:
# 349

# %%
# Para obtener solo tests de 2024 en adelante
df_2024 = get_nordbord_final(token, tenant_id, "2024-01-01")

# Para obtener solo tests de 2025
df_2025 = get_nordbord_final(token, tenant_id, "2025-01-01")
# Out:
# 🚀 Iniciando extracción NordBord filtrada por fecha del test
# 🎯 MÉTODO FINAL: Obtener todos los datos disponibles y filtrar
# 📅 Filtrar tests realizados desde: 2024-01-01
# 📡 Extrayendo datos desde API NordBord (tenant: f1185650-fb79-44a0-8b4b-b2bf82d28c83)
# ⏰ Usando modifiedFromUtc: 2024-01-01T00:00:00.000Z
# 📄 Página 1 - 0 registros acumulados
# ✅ No hay más registros disponibles
# 🎉 Extracción completada: 349 registros en 9 páginas
# 📊 Total de registros obtenidos: 349
# 📅 Columnas de fecha disponibles: ['modifiedDateUtc', 'testDateUtc']
# ✅ Usando columna de fecha del test: 'testDateUtc'
# ✅ Columna 'testDateUtc' convertida a datetime
# 📊 Rango de fechas en los datos: 2023-05-15 a 2025-05-13
# 🔍 Filtrando tests realizados desde: 2024-01-01
# 🎉 Filtrado completado: 345 registros de 349 totales
# 📊 Rango final: 2024-01-09 a 2025-05-13
# 📈 Distribución por año:
#    2024: 226 tests
#    2025: 119 tests
# 🚀 Iniciando extracción NordBord filtrada por fecha del test
# 🎯 MÉTODO FINAL: Obtener todos los datos disponibles y filtrar
# 📅 Filtrar tests realizados desde: 2025-01-01
# 📡 Extrayendo datos desde API NordBord (tenant: f1185650-fb79-44a0-8b4b-b2bf82d28c83)
# ⏰ Usando modifiedFromUtc: 2024-01-01T00:00:00.000Z
# 📄 Página 1 - 0 registros acumulados
# ✅ No hay más registros disponibles
# 🎉 Extracción completada: 349 registros en 9 páginas
# 📊 Total de registros obtenidos: 349
# 📅 Columnas de fecha disponibles: ['modifiedDateUtc', 'testDateUtc']
# ✅ Usando columna de fecha del test: 'testDateUtc'
# ✅ Columna 'testDateUtc' convertida a datetime
# 📊 Rango de fechas en los datos: 2023-05-15 a 2025-05-13
# 🔍 Filtrando tests realizados desde: 2025-01-01
# 🎉 Filtrado completado: 119 registros de 349 totales
# 📊 Rango final: 2025-01-28 a 2025-05-13
# 📈 Distribución por año:
#    2025: 119 tests

# %%
# Obtener datos de ForceFrame
print("\n📊 Obteniendo datos de Nordbord...")
df_nordbord3 = get_nordbord_complete_fixed(token, tenant_id, '2023-01-01T00:00:00.000Z')
# Out:
# 📊 Obteniendo datos de Nordbord...
# 🔄 NUEVA VERSIÓN: Filtrando por fecha del test (no modificación)
# 📅 Tests realizados desde: 2023-01-01T00:00:00.000Z
#
# 🔄 Método 1: Usando períodos de 6 meses
# 🗓️ Dividiendo extracción desde 2023-01-01T00:00:00.000Z hasta 2025-08-19T23:59:59.999Z en períodos de 6 meses
#
# 📅 Período 1: 2023-01-01T00:00:00.000Z a 2023-07-01T23:59:59.999Z
# 🔄 Obteniendo tests NordBord realizados entre 2023-01-01T00:00:00.000Z y 2023-07-01T23:59:59.999Z
# 📡 Usando endpoint /tests con paginación tradicional
# 📄 Procesando página 1
# ❌ Error 400: {"errors":{"TestFromUtc":["'TestFromUtc' must be greater than or equal to '1/1/2023 11:59:59 pm'."]},"type":"https://tools.ietf.org/html/rfc9110#section-15.5.1","title":"One or more validation errors occurred.","status":400,"traceId":"00-7a1fb17fbfb822328ee9b5e5023d954d-a51ec6de21369a0a-00"}
# ⚠️ No se obtuvieron datos
#
# 📅 Período 2: 2023-07-01T00:00:00.000Z a 2024-01-01T23:59:59.999Z
# 🔄 Obteniendo tests NordBord realizados entre 2023-07-01T00:00:00.000Z y 2024-01-01T23:59:59.999Z
# 📡 Usando endpoint /tests con paginación tradicional
# 📄 Procesando página 1
# ❌ Error 400: {"errors":{"TestFromUtc":["'TestFromUtc' must be greater than or equal to '1/7/2023 11:59:59 pm'."]},"type":"https://tools.ietf.org/html/rfc9110#section-15.5.1","title":"One or more validation errors occurred.","status":400,"traceId":"00-18556600e55860b69028d8958667834c-525cf4e05be24ee4-00"}
# ⚠️ No se obtuvieron datos
#
# 📅 Período 3: 2024-01-01T00:00:00.000Z a 2024-07-01T23:59:59.999Z
# 🔄 Obteniendo tests NordBord realizados entre 2024-01-01T00:00:00.000Z y 2024-07-01T23:59:59.999Z
# 📡 Usando endpoint /tests con paginación tradicional
# 📄 Procesando página 1
# ❌ Error 400: {"errors":{"TestFromUtc":["'TestFromUtc' must be greater than or equal to '1/1/2024 11:59:59 pm'."]},"type":"https://tools.ietf.org/html/rfc9110#section-15.5.1","title":"One or more validation errors occurred.","status":400,"traceId":"00-0855d7515b56a57a3b3ddd4e7ebd567c-a7aa0dac8a8867ef-00"}
# ⚠️ No se obtuvieron datos
#
# 📅 Período 4: 2024-07-01T00:00:00.000Z a 2025-01-01T23:59:59.999Z
# 🔄 Obteniendo tests NordBord realizados entre 2024-07-01T00:00:00.000Z y 2025-01-01T23:59:59.999Z
# 📡 Usando endpoint /tests con paginación tradicional
# 📄 Procesando página 1
# ❌ Error 400: {"errors":{"TestFromUtc":["'TestFromUtc' must be greater than or equal to '1/7/2024 11:59:59 pm'."]},"type":"https://tools.ietf.org/html/rfc9110#section-15.5.1","title":"One or more validation errors occurred.","status":400,"traceId":"00-bc24c7981d7fd06f1ca321fa8120202e-bc4dd62720f9ef6a-00"}
# ⚠️ No se obtuvieron datos
#
# 📅 Período 5: 2025-01-01T00:00:00.000Z a 2025-07-01T23:59:59.999Z
# 🔄 Obteniendo tests NordBord realizados entre 2025-01-01T00:00:00.000Z y 2025-07-01T23:59:59.999Z
# 📡 Usando endpoint /tests con paginación tradicional
# 📄 Procesando página 1
# ❌ Error 400: {"errors":{"TestFromUtc":["'TestFromUtc' must be greater than or equal to '1/1/2025 11:59:59 pm'."]},"type":"https://tools.ietf.org/html/rfc9110#section-15.5.1","title":"One or more validation errors occurred.","status":400,"traceId":"00-61896cc1ac4924428a510d37b953d987-d3af32ffd43280e7-00"}
# ⚠️ No se obtuvieron datos
#
# 📅 Período 6: 2025-07-01T00:00:00.000Z a 2025-08-19T23:59:59.999Z
# 🔄 Obteniendo tests NordBord realizados entre 2025-07-01T00:00:00.000Z y 2025-08-19T23:59:59.999Z
# 📡 Usando endpoint /tests con paginación tradicional
# 📄 Procesando página 1
# ✅ Código 204 - No hay más registros
# ⚠️ No se obtuvieron datos
#
# ⚠️ No se obtuvieron datos en ningún período
#
# 🔄 Método 2: Usando rango completo
# 🔄 Obteniendo tests NordBord realizados entre 2023-01-01T00:00:00.000Z y 2025-08-19T23:59:59.999Z
# 📡 Usando endpoint /tests con paginación tradicional
# 📄 Procesando página 1
# ❌ Error 400: {"errors":{"TestFromUtc":["'TestFromUtc' must be greater than or equal to '19/2/2025 11:59:59 pm'."]},"type":"https://tools.ietf.org/html/rfc9110#section-15.5.1","title":"One or more validation errors occurred.","status":400,"traceId":"00-27104914ab9b284c501773546991c874-84a373d0e01fb545-00"}
# ⚠️ No se obtuvieron datos

# %%
# exportar la notebook a html
